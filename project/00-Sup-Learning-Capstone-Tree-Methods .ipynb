# %% [markdown]
# ___
#
# <a href='https://rt-ed.co.il/'> <img src='https://rt-ed.co.il/wp-content/uploads/2020/06/logo-svg.svg' width=193 height=130 /></a>
# ___

# %% [markdown]
# # Supervised Learning Capstone Project - Tree Methods Focus
#
#
#
#
# ----
#
# **Ways to approach the project:**
#    1. Open a new notebook, read in the data, and then analyze and visualize whatever you want, then create a predictive model.
#    2. Use this notebook as a general guide, completing the tasks in bold shown below.
#    3. Skip to the solutions notebook and video, and treat project at a more relaxing code along walkthrough lecture series.
#
# ------
# ------
#
# ## GOAL: Create a model to predict whether or not a customer will Churn .
#
# ----
# ----
#
#
# ## Complete the Tasks in Bold Below!
#
# ## Part 0: Imports and Read in the Data
#
# **TASK: Run the filled out cells below to import libraries and read in your data. The data file is "Telco-Customer-Churn.csv"**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\amita\anaconda3\envs\DataScience\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
customer_Churn=pd.read_csv("Telco-Customer-Churn - Original.csv")

# %%
customer_Churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Part 1: Quick Data Check
#
# **TASK: Confirm quickly with .info() methods the datatypes and non-null values in your dataframe.**

# %% [markdown]
# משום שיש 7042 שורות ומתוכן 11 שורות לא טובות בגלל שבאחד העמודות חסר מידע
# שזה 0.156 אחוז מכול המידע שהוא לא טוב שזה כלום לכן נמצא את השורות הנ"ל ונוריד אותן

# %%
def if_nomri(x):
    if isinstance(x,(str,float)):
        if isinstance(x,(str)):
            if x.replace('.','').isnumeric():
                return True
        return False
    else:
        return False

# %%
tmp=customer_Churn[['TotalCharges','MonthlyCharges']]
tmp=tmp['TotalCharges'].apply(if_nomri)
tmp[tmp==False].index
customer_Churn.drop([488, 753, 936, 1082, 1340, 3331, 3826, 4380, 5218, 6670, 6754],inplace=True)
customer_Churn['TotalCharges']=pd.to_numeric(customer_Churn['TotalCharges'])

# %%
customer_Churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   object
#  17  PaymentMethod     7032 non-null   object
#  18  MonthlyCharges    7032 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7032 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7032 entries, 0 to 7031
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
#  16  PaperlessBilling  7032 non-null   object
#  17  PaymentMethod     7032 non-null   object
#  18  MonthlyCharges    7032 non-null   float64
#  19  TotalCharges      7032 non-null   float64
#  20  Churn             7032 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %% [markdown]
# **TASK: Get a quick statistical summary of the numeric columns with .describe() , you should notice that many columns are categorical, meaning you will eventually need to convert them to dummy variables.**

# %%
customer_Churn.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# # Part 2:  Exploratory Data Analysis
#
# ## General Feature Exploration
#
# **TASK: Confirm that there are no NaN cells by displaying NaN values per feature column.**

# %%
customer_Churn.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# **TASK:Display the balance of the class labels (Churn) with a Count Plot.**

# %%
sns.countplot(data=customer_Churn,x='Churn')
plt.xlabel('Churn')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# <img src='fig1.png' >

# %% [markdown]
# **TASK: Explore the distrbution of TotalCharges between Churn categories with a Box Plot or Violin Plot.**

# %%
sns.violinplot(data=customer_Churn,x="Churn",y="TotalCharges")
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='TotalCharges'>

# %% [markdown]
# <img src='fig2.png' >

# %% [markdown]
# **TASK: Create a boxplot showing the distribution of TotalCharges per Contract type, also add in a hue coloring based on the Churn class.**

# %%
fig, ax = plt.subplots(figsize=(14,6))
sns.boxplot(data=customer_Churn,x='Contract',y='TotalCharges',hue='Churn')
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='TotalCharges'>

# %% [markdown]
# <img src='fig3.png' >

# %% [markdown]
# **TASK: Create a bar plot showing the correlation of the following features to the class label. Keep in mind, for the categorical features, you will need to convert them into dummy variables first, as you can only calculate correlation for numeric features.**
#
#     ['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines',
#      'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'InternetService',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
#
# ***Note, we specifically listed only the features above, you should not check the correlation for every feature, as some features have too many unique instances for such an analysis, such as customerID***

# %%
customer_Churn_num=pd.get_dummies(data=customer_Churn[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines', 
 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'InternetService',
   'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod','Churn']])

# %%
customer_Churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
corr_df=pd.get_dummies(data=customer_Churn[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines', 
 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'InternetService',
   'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod','Churn']]).corr()
corr_df['Churn_Yes'].sort_values().iloc[1:-1]
# Out:
# Contract_Two year                         -0.301552
# DeviceProtection_No internet service      -0.227578
# StreamingMovies_No internet service       -0.227578
# StreamingTV_No internet service           -0.227578
# InternetService_No                        -0.227578
# TechSupport_No internet service           -0.227578
# OnlineBackup_No internet service          -0.227578
# OnlineSecurity_No internet service        -0.227578
# PaperlessBilling_No                       -0.191454
# Contract_One year                         -0.178225
# OnlineSecurity_Yes                        -0.171270
# TechSupport_Yes                           -0.164716
# Dependents_Yes                            -0.163128
# Partner_Yes                               -0.149982
# PaymentMethod_Credit card (automatic)     -0.134687
# InternetService_DSL                       -0.124141
# PaymentMethod_Bank transfer (automatic)   -0.118136
# PaymentMethod_Mailed check                -0.090773
# OnlineBackup_Yes                          -0.082307
# DeviceProtection_Yes                      -0.066193
# MultipleLines_No                          -0.032654
# MultipleLines_No phone service            -0.011691
# PhoneService_No                           -0.011691
# gender_Male                               -0.008545
# gender_Female                              0.008545
# PhoneService_Yes                           0.011691
# MultipleLines_Yes                          0.040033
# StreamingMovies_Yes                        0.060860
# StreamingTV_Yes                            0.063254
# StreamingTV_No                             0.128435
# StreamingMovies_No                         0.130920
# Partner_No                                 0.149982
# SeniorCitizen                              0.150541
# Dependents_No                              0.163128
# PaperlessBilling_Yes                       0.191454
# DeviceProtection_No                        0.252056
# OnlineBackup_No                            0.267595
# PaymentMethod_Electronic check             0.301455
# InternetService_Fiber optic                0.307463
# TechSupport_No                             0.336877
# OnlineSecurity_No                          0.342235
# Contract_Month-to-month                    0.404565
# Name: Churn_Yes, dtype: float64

# %%
# Out:
# Contract_Two year                         -0.301552
# StreamingMovies_No internet service       -0.227578
# StreamingTV_No internet service           -0.227578
# TechSupport_No internet service           -0.227578
# DeviceProtection_No internet service      -0.227578
# OnlineBackup_No internet service          -0.227578
# OnlineSecurity_No internet service        -0.227578
# InternetService_No                        -0.227578
# PaperlessBilling_No                       -0.191454
# Contract_One year                         -0.178225
# OnlineSecurity_Yes                        -0.171270
# TechSupport_Yes                           -0.164716
# Dependents_Yes                            -0.163128
# Partner_Yes                               -0.149982
# PaymentMethod_Credit card (automatic)     -0.134687
# InternetService_DSL                       -0.124141
# PaymentMethod_Bank transfer (automatic)   -0.118136
# PaymentMethod_Mailed check                -0.090773
# OnlineBackup_Yes                          -0.082307
# DeviceProtection_Yes                      -0.066193
# MultipleLines_No                          -0.032654
# MultipleLines_No phone service            -0.011691
# PhoneService_No                           -0.011691
# gender_Male                               -0.008545
# gender_Female                              0.008545
# PhoneService_Yes                           0.011691
# MultipleLines_Yes                          0.040033
# StreamingMovies_Yes                        0.060860
# StreamingTV_Yes                            0.063254
# StreamingTV_No                             0.128435
# StreamingMovies_No                         0.130920
# Partner_No                                 0.149982
# SeniorCitizen                              0.150541
# Dependents_No                              0.163128
# PaperlessBilling_Yes                       0.191454
# DeviceProtection_No                        0.252056
# OnlineBackup_No                            0.267595
# PaymentMethod_Electronic check             0.301455
# InternetService_Fiber optic                0.307463
# TechSupport_No                             0.336877
# OnlineSecurity_No                          0.342235
# Contract_Month-to-month                    0.404565
# Name: Churn_Yes, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.barplot(x=corr_df['Churn_Yes'].sort_values().iloc[1:-1].index,y=corr_df['Churn_Yes'].sort_values().iloc[1:-1].values)
plt.title("Feature Correlation to Yes Churn")
plt.xticks(rotation=90);

# %% [markdown]
# <img src='figbar.png'>

# %% [markdown]
# ---
# ---
#
# # Part 3: Churn Analysis
#
# **This section focuses on segementing customers based on their tenure, creating "cohorts", allowing us to examine differences between customer cohort segments.**

# %% [markdown]
# **TASK: What are the 3 contract types available?**

# %%
customer_Churn['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %% [markdown]
# **TASK: Create a histogram displaying the distribution of 'tenure' column, which is the amount of months a customer was or has been on a customer.**

# %%
customer_Churn['tenure'].hist(grid=False,bins=70,figsize=(14,6),ec='black',xlabelsize=13)
plt.xlabel('tenure',fontsize=15)
plt.ylabel('count',fontsize=15)
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# <img src="fig5.png">

# %% [markdown]
# **TASK: Now use the seaborn documentation as a guide to create histograms separated by two additional features, Churn and Contract.**

# %%
sns.displot(data=customer_Churn[['Churn',"tenure","Contract"]], x="tenure", row='Churn',col="Contract",bins=70)

# %% [markdown]
# <img src="fig6.png">

# %% [markdown]
# **TASK: Display a scatter plot of Total Charges versus Monthly Charges, and color hue by Churn.**

# %%
customer_Churn.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=customer_Churn,x="MonthlyCharges",y='TotalCharges',hue='Churn',sizes=(5,100))
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %% [markdown]
# <img src='fig7.png'>

# %% [markdown]
# ### Creating Cohorts based on Tenure
#
# **Let's begin by treating each unique tenure length, 1 month, 2 month, 3 month...N months as its own cohort.**
#
# **TASK: Treating each unique tenure group as a cohort, calculate the Churn rate (percentage that had Yes Churn) per cohort. For example, the cohort that has had a tenure of 1 month should have a Churn rate of 61.99%. You should have cohorts 1-72 months with a general trend of the longer the tenure of the cohort, the less of a churn rate. This makes sense as you are less likely to stop service the longer you've had it.**

# %%
customer_Churn_mon=customer_Churn[['Churn','tenure']][customer_Churn['Churn']=='Yes'].groupby('tenure').count()

# %%
customer_Churn_mon=(customer_Churn_mon/customer_Churn[['tenure','Churn']].groupby('tenure').count())*100
customer_Churn_mon.rename(columns={'Churn':'Churn Percentage'}, inplace=True)

# %%
customer_Churn_mon
# Out:
#         Churn Percentage
# tenure
# 1              61.990212
# 2              51.680672
# 3              47.000000
# 4              47.159091
# 5              48.120301
# ...                  ...
# 68              9.000000
# 69              8.421053
# 70              9.243697
# 71              3.529412
# 72              1.657459
#
# [72 rows x 1 columns]

# %%
# Out:
# tenure
# 1     61.990212
# 2     51.680672
# 3     47.000000
# 4     47.159091
# 5     48.120301
#         ...
# 68     9.000000
# 69     8.421053
# 70     9.243697
# 71     3.529412
# 72     1.657459
# Name: customerID, Length: 72, dtype: float64

# %% [markdown]
# **TASK: Now that you have Churn Rate per tenure group 1-72 months, create a plot showing churn rate per months of tenure.**

# %%
customer_Churn_mon.plot(figsize=(15,7),ylabel='Churn Percentage',fontsize=14,legend=False)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Churn Percentage'>

# %% [markdown]
# <img src='fig9.png'>

# %% [markdown]
# ### Broader Cohort Groups
# **TASK: Based on the tenure column values, create a new column called Tenure Cohort that creates 4 separate categories:**
#    * '0-12 Months'
#    * '12-24 Months'
#    * '24-48 Months'
#    * 'Over 48 Months'

# %%
def tenure_cohort(x):
    if x<13:
        return "0-12 Months"
    elif x<25:
        return '12-24 Months'
    elif x<49:
        return '24-48 Months'
    else:
        return 'Over 48 Months'

# %%
customer_Churn['Tenure Cohort'] = customer_Churn['tenure'].apply(tenure_cohort)

# %%
customer_Churn[['tenure','Tenure Cohort']].head(10)
# Out:
#    tenure   Tenure Cohort
# 0       1     0-12 Months
# 1      34    24-48 Months
# 2       2     0-12 Months
# 3      45    24-48 Months
# 4       2     0-12 Months
# 5       8     0-12 Months
# 6      22    12-24 Months
# 7      10     0-12 Months
# 8      28    24-48 Months
# 9      62  Over 48 Months

# %%
# Out:
#    tenure   Tenure Cohort
# 0       1     0-12 Months
# 1      34    24-48 Months
# 2       2     0-12 Months
# 3      45    24-48 Months
# 4       2     0-12 Months
# 5       8     0-12 Months
# 6      22    12-24 Months
# 7      10     0-12 Months
# 8      28    24-48 Months
# 9      62  Over 48 Months

# %% [markdown]
# **TASK: Create a scatterplot of Total Charges versus Monthly Charts,colored by Tenure Cohort defined in the previous task.**

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=customer_Churn,x="MonthlyCharges",y='TotalCharges',hue='Tenure Cohort',sizes=(5,100))
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %% [markdown]
# <img src='fig10.png'>

# %% [markdown]
# **TASK: Create a count plot showing the churn count per cohort.**

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=customer_Churn,x='Tenure Cohort',hue='Churn')
plt.xlabel('Churn')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# <img src='cplot.png'>

# %% [markdown]
# **TASK: Create a grid of Count Plots showing counts per Tenure Cohort, separated out by contract type and colored by the Churn hue.**

# %%
sns.displot(data=customer_Churn, x="Tenure Cohort", col='Contract',hue='Churn', multiple="dodge")

# %% [markdown]
# <img src='fig11.png'>

# %% [markdown]
# -----
#
# # Part 4: Predictive Modeling
#
# **Let's explore 4 different tree based methods: A Single Decision Tree, Random Forest, AdaBoost, Gradient Boosting. Feel free to add any other supervised learning models to your comparisons!**
#
#
# ## Single Decision Tree

# %% [markdown]
# **TASK : Separate out the data into X features and Y label. Create dummy variables where necessary and note which features are not useful and should be dropped.**

# %%
X = customer_Churn.drop(['Churn','customerID'], axis=1)
X = pd.get_dummies(X, drop_first=True)
y = customer_Churn['Churn']

# %% [markdown]
# **TASK: Perform a train test split, holding out 10% of the data for testing. We'll use a random_state of 101 in the solutions notebook/video.**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=101)

# %% [markdown]
# **TASK: Decision Tree Perfomance. Complete the following tasks:**
#    1. Train a single decision tree model (feel free to grid search for optimal hyperparameters).
#    2. Evaluate performance metrics from decision tree, including classification report and plotting a confusion matrix.
#    2. Calculate feature importances from the decision tree.
#    4. OPTIONAL: Plot your tree, note, the tree could be huge depending on your pruning, so it may crash your notebook if you display it with plot_tree.

# %% [markdown]
# from sklearn.model_selection import GridSearchCV
#
# param_grid = {
#               'ccp_alpha': [0.1, .01,00.5, 0.001,0.0001],
#               'max_depth' : [5, 6, 7, 8, 9,10,11,13,15],
#               'criterion' :['gini', 'entropy'],
#               'splitter': ['best','random'],
#               'min_samples_leaf': [1,2,3,4,5,6,7,8,9],
#               'min_samples_split': [1,2,3,4,5,6,7,8,9],
#               'min_weight_fraction_leaf': [0,0.1,0.3,0.4] ,
#               'max_features': ['sqrt', 'log2']
#              }
# tree_clas = DecisionTreeClassifier(random_state=1024)
# grid_search = GridSearchCV(estimator=tree_clas, param_grid=param_grid, cv=3, verbose=True)
# grid_search.fit(X_train, y_train)
# final_model = grid_search.best_estimator_
# final_model

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier(max_depth=6,random_state=101)

dtree.fit(X_train,y_train)
y_predict=dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,plot_confusion_matrix

# %%
print(classification_report(y_test,y_predict) )
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.89      0.88       557
#          Yes       0.55      0.49      0.52       147
#
#     accuracy                           0.81       704
#    macro avg       0.71      0.69      0.70       704
# weighted avg       0.80      0.81      0.80       704

# %%
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.89      0.88       557
#          Yes       0.55      0.49      0.52       147
#
#     accuracy                           0.81       704
#    macro avg       0.71      0.69      0.70       704
# weighted avg       0.80      0.81      0.81       704

# %%
plot_confusion_matrix(estimator=dtree, X=X_test, y_true=y_test, cmap="GnBu")
# Out:
# C:\Users\amita\anaconda3\envs\DataScience\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
plt.figure(figsize=(14, 6))
imp_feature=pd.DataFrame(index=X.columns,data=dtree.feature_importances_,columns=['Importance']).sort_values('Importance')
sns.barplot(data=imp_feature.sort_values('Importance'), x=imp_feature.sort_values('Importance').index,y='Importance')
plt.xticks(rotation=90);

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(14, 6))
plot_tree(dtree, filled=True, feature_names=X.columns);

# %% [markdown]
# <img src='hugetree.png'>

# %% [markdown]
# ## Random Forest
#
# **TASK: Create a Random Forest model and create a classification report and confusion matrix from its predicted results on the test set.**

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=300)
rf_model.fit(X_train,y_train)
y_pred=rf_model.predict(X_test)
print(classification_report(y_test,y_pred) )
# Out:
#               precision    recall  f1-score   support
#
#           No       0.86      0.89      0.87       557
#          Yes       0.52      0.45      0.48       147
#
#     accuracy                           0.80       704
#    macro avg       0.69      0.67      0.68       704
# weighted avg       0.79      0.80      0.79       704

# %%
# Out:
#               precision    recall  f1-score   support
#
#           No       0.86      0.89      0.87       557
#          Yes       0.52      0.44      0.48       147
#
#     accuracy                           0.80       704
#    macro avg       0.69      0.67      0.68       704
# weighted avg       0.79      0.80      0.79       704

# %%
plot_confusion_matrix(estimator=rf_model, X=X_test, y_true=y_test, cmap="GnBu")
# Out:
# C:\Users\amita\anaconda3\envs\DataScience\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Boosted Trees
#
# **TASK: Use AdaBoost or Gradient Boosting to create a model and report back the classification report and plot a confusion matrix for its predicted results**

# %%
from sklearn.ensemble import AdaBoostClassifier
ada_model = AdaBoostClassifier()
ada_model.fit(X_train, y_train)
y_pred=ada_model.predict(X_test)
print(classification_report(y_test,y_pred) )
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.90      0.89       557
#          Yes       0.60      0.54      0.57       147
#
#     accuracy                           0.83       704
#    macro avg       0.74      0.72      0.73       704
# weighted avg       0.82      0.83      0.83       704

# %%
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.90      0.89       557
#          Yes       0.60      0.54      0.57       147
#
#     accuracy                           0.83       704
#    macro avg       0.74      0.72      0.73       704
# weighted avg       0.82      0.83      0.83       704

# %%
plot_confusion_matrix(estimator=ada_model, X=X_test, y_true=y_test, cmap="GnBu")
# Out:
# C:\Users\amita\anaconda3\envs\DataScience\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# **TASK: Analyze your results, which model performed best for you?**

# %% [markdown]
# #### With base models, we got best performance from an AdaBoostClassifier, but note, we didn't do any gridsearching AND most models performed about the same on the data set.

# %% [markdown]
# ### Great job!
